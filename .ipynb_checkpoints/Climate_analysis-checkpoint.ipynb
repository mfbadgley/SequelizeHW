# %%
from sqlalchemy import create_engine, inspect, func, desc
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import Column, Integer, String, Float
import pymysql
import pandas as pd

# %%
engine = create_engine("sqlite:///hawaii.sqlite")
conn = engine.connect()

# %%
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# []

# %%
#inspect the columns, datatype
inspector = inspect(engine)
columns = inspector.get_columns('measurements')
for c in columns:
    print(c['name'], c["type"])
# Out:
# station TEXT
# date TEXT
# prcp FLOAT
# tobs BIGINT

# %%
# Assign the CLASSes to a variables
measurements = Base.classes.measurements
station = Base.classes.Station
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'measurements'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-577c7f31d9fa> in <module>()
#       1 # Assign the CLASSes to a variables
# ----> 2 measurements = Base.classes.measurements
#       3 station = Base.classes.Station
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
# ...

# %%
# Create a session
session = Session(engine)

# %%
# Earliest Date
session.query(measurements.date).order_by(measurements.date).first()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9c29645da079> in <module>()
#       1 # Earliest Date
# ----> 2 session.query(measurements.date).order_by(measurements.date).first()
#
# NameError: name 'measurements' is not defined

# %%
# Latest Date
session.query(measurements.date).order_by(measurements.date.desc()).first()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-26ef3bffaa32> in <module>()
#       1 # Latest Date
# ----> 2 session.query(measurements.date).order_by(measurements.date.desc()).first()
#
# NameError: name 'measurements' is not defined

# %%
prcp_data =session.query(measurements.date, measurements.prcp).\
    filter(measurements.date >= '2016-08-23').all()
prcp_data
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', 0.16064353974479206),
#  ('2016-09-06', 0.16064353974479206),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
# ...

# %%
prcp_df = pd.DataFrame(prcp_data)

# %%
prcp_df.describe()
# Out:
#               prcp
# count  2230.000000
# mean      0.175720
# std       0.439063
# min       0.000000
# 25%       0.000000
# 50%       0.030000
# 75%       0.160644
# max       6.700000

# %%
prcp_df.set_index('date', inplace=True)
prcp_df.head()
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-24  0.08
# 2016-08-25  0.08
# 2016-08-26  0.00
# 2016-08-27  0.00

# %%
import matplotlib
from matplotlib import style
import matplotlib.pyplot as plt

# %%
prcp_df.plot(figsize=(15,5))
plt.tight_layout()
plt.title("Avg Daily Precipitation 8/16/23 thru 8/17/23")
plt.ylabel('Inches')
plt.xticks(rotation=45)
plt.savefig('AvgDailyPrecipitation')
plt.show()

# %%
#list of all the stations
engine.execute('SELECT * FROM station').fetchall()
# Out:
# [('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  ('USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  ('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %%
#stations ordered by observation count, descending
q = session.query(measurements.station, func.count(measurements.tobs)).\
    group_by(measurements.station).order_by(desc(func.count(measurements.tobs))).all()
q
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
#the most active station, observation count
q2 = session.query(measurements.station, func.count(measurements.tobs)).\
    group_by(measurements.station).order_by(desc(func.count(measurements.tobs))).first()
busiest=q2
print(busiest[0])
# Out:
# USC00519281

# %%
#last 12 months of temperature data, at the busiest station over last 12 months
tobs_data = session.query(measurements.station, func.count(measurements.tobs)).group_by(measurement.station).\
    filter(measurements.date >= '2016-08-23').all()
tobs_data
# Out:
# [('USC00513117', 343),
#  ('USC00514830', 305),
#  ('USC00516128', 349),
#  ('USC00517948', 183),
#  ('USC00519281', 352),
#  ('USC00519397', 361),
#  ('USC00519523', 337)]

# %%
#busiest station over last 12 months
# find station w/ most observations in past 12 months
station_12mos = session.query(measurements.station, func.count(measurements.tobs)).\
filter(measurements.date >= '2016-08-23').group_by(measurements.station).order_by(func.count(measurements.tobs).desc()).first()
station_12mos
# Out:
# ('USC00519397', 361)

# %%
#return last 12 months temp measurements for busiest station
station_tobs = session.query(measurements.date, measurements.tobs).order_by(measurements.date.asc()).\
filter(measurements.date >= '2016-08-23', measurements.station == station_12mos[0]).all()
station_tobs
# Out:
# [('2016-08-23', 81),
#  ('2016-08-24', 79),
#  ('2016-08-25', 80),
#  ('2016-08-26', 79),
#  ('2016-08-27', 77),
#  ('2016-08-28', 78),
#  ('2016-08-29', 78),
#  ('2016-08-30', 79),
#  ('2016-08-31', 80),
#  ('2016-09-01', 81),
#  ('2016-09-02', 80),
#  ('2016-09-03', 79),
#  ('2016-09-04', 75),
#  ('2016-09-05', 79),
#  ('2016-09-06', 76),
#  ('2016-09-07', 76),
#  ('2016-09-08', 80),
#  ('2016-09-09', 79),
#  ('2016-09-10', 78),
#  ('2016-09-11', 76),
#  ('2016-09-12', 78),
#  ('2016-09-13', 78),
#  ('2016-09-14', 75),
#  ('2016-09-15', 79),
#  ('2016-09-16', 80),
#  ('2016-09-17', 79),
#  ('2016-09-18', 81),
#  ('2016-09-19', 77),
#  ('2016-09-20', 77),
#  ('2016-09-21', 78),
#  ('2016-09-22', 76),
#  ('2016-09-23', 82),
#  ('2016-09-24', 81),
#  ('2016-09-25', 78),
#  ('2016-09-26', 80),
#  ('2016-09-27', 80),
#  ('2016-09-28', 79),
#  ('2016-09-29', 80),
#  ('2016-09-30', 80),
#  ('2016-10-01', 80),
#  ('2016-10-02', 79),
#  ('2016-10-03', 79),
#  ('2016-10-04', 79),
# ...

# %%
busiest_df = pd.DataFrame(station_tobs)
busiest_df.set_index('date', inplace=True)
busiest_df.head()
# Out:
#             tobs
# date
# 2016-08-23    81
# 2016-08-24    79
# 2016-08-25    80
# 2016-08-26    79
# 2016-08-27    77

# %%
plt.hist(busiest_df['tobs'],12)
plt.xlabel("Recorded Temperature")
plt.ylabel("Number of Recorded Observations")
plt.title("Station Analysis (8/24/16 to 8/23/17) for Station " + str(busiest[0]))
plt.show()

# %%
#Write a function called calc_temps that will accept a start date 
#and end date in the format %Y-%m-%d and return the minimum, average, 
#and maximum temperatures for that range of dates.

# %%
def calc_temps(start_date, end_date):
    tobs = session.query(measurements.tobs).\
    filter (and_(measurements.date >= start_date, measurements.date<= end_date))
    return tobs

# %%
start_date =str(input("What is your start date (YYYY-MM-DD): "))
end_date = str(input("What is your end date (YYYY-MM-DD): "))
# Out:
# What is your start date (YYYY-MM-DD): 2016-04-23
# What is your end date (YYYY-MM-DD): 2016-05-23

# %%
calc_temps(start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-69f6c4467993> in <module>()
# ----> 1 calc_temps(start_date, end_date)
#
# <ipython-input-7-d96c637f1bf9> in calc_temps(start_date, end_date)
#       1 def calc_temps(start_date, end_date):
# ----> 2     tobs = session.query(measurements.tobs).    filter (and_(measurements.date >= start_date, measurements.date<= end_date))
#       3     return tobs
#
# NameError: name 'session' is not defined
