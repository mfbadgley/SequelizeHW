# %%
import pandas as pd

# %%
# Create a reference the CSV file desired
csv_path = "hawaii_measurements.csv"
csv_path2 = "hawaii_stations.csv"

# Read the CSV into a Pandas DataFrame
measurements_df = pd.read_csv(csv_path)
stations_df=pd.read_csv(csv_path2)

# Print the first five rows of data to the screen
measurements_df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
stations_df.head()
# Out:
#        station                                    name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1  USC00513117                    KANEOHE 838.1, HI US   21.4234  -157.8015
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213  -157.8374
# 3  USC00517948                       PEARL CITY, HI US   21.3934  -157.9751
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992  -158.0111
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6

# %%
measurements_df.describe()
# Out:
#                prcp          tobs
# count  18103.000000  19550.000000
# mean       0.160644     73.097954
# std        0.468746      4.523527
# min        0.000000     53.000000
# 25%        0.000000     70.000000
# 50%        0.010000     73.000000
# 75%        0.110000     76.000000
# max       11.530000     87.000000

# %%
stations_df.describe()
# Out:
#         latitude   longitude   elevation
# count   9.000000    9.000000    9.000000
# mean   21.393826 -157.867098   60.977778
# std     0.086442    0.103873  103.465547
# min    21.271600 -158.011100    0.900000
# 25%    21.333100 -157.975100    7.000000
# 50%    21.393400 -157.837400   14.600000
# 75%    21.451670 -157.802500   32.900000
# max    21.521300 -157.711390  306.600000

# %%
clean_measurements=measurements_df.fillna(measurements_df.mean())

# %%
clean_measurements.head()
# Out:
#        station        date      prcp  tobs
# 0  USC00519397  2010-01-01  0.080000    65
# 1  USC00519397  2010-01-02  0.000000    63
# 2  USC00519397  2010-01-03  0.000000    74
# 3  USC00519397  2010-01-04  0.000000    76
# 4  USC00519397  2010-01-06  0.160644    73

# %%
clean_measurements.describe()
# Out:
#                prcp          tobs
# count  19550.000000  19550.000000
# mean       0.160644     73.097954
# std        0.451064      4.523527
# min        0.000000     53.000000
# 25%        0.000000     70.000000
# 50%        0.020000     73.000000
# 75%        0.160644     76.000000
# max       11.530000     87.000000

# %%
stations_df
# Out:
#        station                                    name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# 1  USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# 3  USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# 5  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# 6  USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# 7  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 8  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6
# 5       19.5
# 6       32.9
# 7        0.9
# 8      152.4

# %%
#clean_measurements['date'] =  pd.to_datetime(clean_measurements['date'], format='%Y-%m-%d')

# %%
clean_measurements.dtypes
# Out:
# station     object
# date        object
# prcp       float64
# tobs         int64
# dtype: object

# %%
clean_measurements.to_csv("clean_measurements.csv")

# %%
clean_measurements.isnull().values.any()
# Out:
# False
